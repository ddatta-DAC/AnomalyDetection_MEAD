# %% [markdown]
# # Case study based on US Imports
#
# ## train on on data : 8 months of 2015
# ## use next 4 months as test data ( no filtering)
# ## analyze results with low score - find a transaction such that the combination of 2 entities is rare and also covered by some filter.
# ## test on just test data, no anomalies injected

# %%
import pandas as pd 
import numpy as np
import pickle
import os
import sys
import itertools
from itertools import combinations

# %%
DATA_DIR = 'generated_data'
_DIR = 'us_import'
id_col ='PanjivaRecordID'

# %%
train_df = pd.read_csv(os.path.join(DATA_DIR, _DIR, 'train_data.csv'))
test_df = pd.read_csv(os.path.join(DATA_DIR, _DIR, 'test_data.csv'))

# %%
test_df.head(10)
# Out:
#    PanjivaRecordID  Carrier  ConsigneePanjivaID  PortOfLading  PortOfUnlading  \
# 0        114779263      180                2830           212              15
# 1        113632447       44                5436            38              51
# 2        113695935       14                2625            38              51
# 3        113721855      127                3301           199              15
# 4        113688319      514                4012           142              51
# 5        113695487       84                5929           142              51
# 6        113732799       44                 281            46              63
# 7        113701823      538                3141            46              14
# 8        113722943      127                 413            46              15
# 9        113674047      376                 432            38              15
#
#    ShipmentDestination  ShipmentOrigin  ShipperCountry  ShipperPanjivaID  \
# 0                  104             116             115              2362
# 1                   15              81              81              4013
# 2                   30              81              81              4231
# 3                   82              81              81              4135
# 4                   44              81              81              1364
# 5                   99              81              81                20
# 6                   56              81              81              3722
# 7                  103              81              81              5073
# 8                  104              81              81              2007
# 9                  104              81              81              6255
#
#    hscode_6
# 0        64
# 1        50
# 2        21
# 3         6
# 4        45
# 5        21
# 6        26
# 7        50
# 8        50
# 9        21

# %%
result_df = pd.read_csv(os.path.join('output', _DIR, 'result_1.csv'))

# %%
anomaly_id_list  = result_df['PanjivaRecordID']
score_list = list(result_df['score'])

# %%
col_val2id_dict_file = os.path.join( DATA_DIR, _DIR, 'col_val2id_dict.pkl' )
with open(col_val2id_dict_file,'rb') as fh:
    col_val2id_dict = pickle.load(fh)

col_id2val_dict = {}
for attr, _dict in col_val2id_dict.items():
    col_id2val_dict[attr] = { v:k  for k,v in _dict.items() }

# %%
def convert_row2vals( _row_dict, col_id2val_dict ):
    res = {}
    for k, v in _row_dict.items() :
        res[k] = col_id2val_dict[k][v]
    return res

# %%
hdf_df = pd.read_csv('collated_hscode_filters.csv')
tmp = hdf_df.loc[hdf_df['count']>=1]

hdf_list = list(tmp['hscode_6'])

# %%
with open(os.path.join('output', _DIR, 'train_embeddings.pkl'),'rb') as fh:
    train_x_emb = pickle.load(fh)
with open(os.path.join(DATA_DIR, _DIR, 'domain_dims.pkl'),'rb') as fh:
    domain_dims =  pickle.load(fh)

# %%
train_x_emb.shape
# Out:
# (222443, 9, 12)

# %%
train_x_pos_file = os.path.join(
    DATA_DIR,
    _DIR,
    'matrix_train_positive_v1.pkl'
)

with open(train_x_pos_file, 'rb') as fh:
    train_x = pickle.load(fh)

# %%
train_x.shape
# Out:
# (222443, 9)

# %%
emb_size = train_x_emb.shape[-1]
domain_sizes = list(domain_dims.values())
domain_names = list(domain_dims.keys())
domain_emb_dict = {}
domain_id2name = {e[0]:e[1] for e in enumerate(domain_names,0)}
domain_name2id = {e[1]:e[0] for e in enumerate(domain_names,0)}

# %%
domain_id2name
# Out:
# {0: 'Carrier',
#  1: 'ConsigneePanjivaID',
#  2: 'PortOfLading',
#  3: 'PortOfUnlading',
#  4: 'ShipmentDestination',
#  5: 'ShipmentOrigin',
#  6: 'ShipperCountry',
#  7: 'ShipperPanjivaID',
#  8: 'hscode_6'}

# %%
for _ds,_dn in zip(domain_sizes, domain_names):
    a = np.zeros([_ds,emb_size])
    domain_emb_dict[_dn] = a

num_cols =  train_x_emb.shape[1]

# %%
for c in range(num_cols):
    ids = train_x[:,c]
    vals = train_x_emb[:,c,:]
    ids = np.reshape(ids,[-1,1])
    tmp = np.hstack([ids,vals])
    _df = pd.DataFrame(tmp)
    _df = _df.rename(columns={0:'id'})
    _df = _df.drop_duplicates(subset=['id'])
   
    for i,row in _df.iterrows():
        _id = int(row['id'])
        z = row.values
        _name = domain_id2name[c]
        domain_emb_dict[_name][_id] = z[1:]

# %%
domain_id2name
# Out:
# {0: 'Carrier',
#  1: 'ConsigneePanjivaID',
#  2: 'PortOfLading',
#  3: 'PortOfUnlading',
#  4: 'ShipmentDestination',
#  5: 'ShipmentOrigin',
#  6: 'ShipperCountry',
#  7: 'ShipperPanjivaID',
#  8: 'hscode_6'}

# %%
def get_embedding(id_value, domain_id, domain_emb_dict):
    global domain_id2name
    print(id_value)
    domain_name = domain_id2name[domain_id]
    return domain_emb_dict[domain_name][id_value]

def get_emb_arr(arr, domain_emb_dict):
    tmp = []
    for i in range(len(arr)):
        v = get_embedding(arr[i], i, domain_emb_dict)
        tmp.append(v)
    tmp = np.array(tmp)
    return tmp

def dissect(arr):
    p = [_/np.linalg.norm(_, ord=2) for _ in arr]
    arr_sum = np.mean(arr,axis=0)
    
    res = []
    for i in range(arr.shape[0]):
        x = arr[i]
        prj = np.dot(arr_sum,x)/np.linalg.norm(arr_sum, ord=2)
        res.append(prj)
    res = np.array(res)
    return res

# %%
# create a list of valid PanjivaIDs where HS Code filters match

# %%
def investigate(target_id, train_df, test_df,_score):
    global id_col
    global hdf_list
    global col_id2val_dict
    global domain_emb_dict
    target_row = test_df.loc[test_df[id_col]==target_id].squeeze()
    print('ID ',target_row['PanjivaRecordID'])
    del target_row['PanjivaRecordID']
    print(target_row)
    arr = list(target_row)
    
    val_dict = convert_row2vals( target_row.to_dict(), col_id2val_dict )
    if val_dict['hscode_6'] in hdf_list:
        print('-------------> Filter Valid')
        print('Score ',_score)
    else: 
        return   
    row_emb = get_emb_arr(arr,domain_emb_dict)
    prj = dissect(row_emb)
    _mean = np.mean(prj)
    
    for i,j in zip(list(target_row.to_dict().keys()),prj):
        if j < _mean:
            print ('::>', i, j)
        else:
            print ('[[', i, j, ']]')
   
    print(val_dict)
    attributes = list(target_row.to_dict()) 
    
    for comb in combinations(attributes, 2):
        query_str = []
        for _c in comb:
            val =  target_row[_c]
            if _c == id_col:
                continue    
            query_str.append(' ' + _c + ' == ' + str(val))
        query_str = ' & '.join(query_str)
        
        res_query = train_df.query(query_str)
#         if res_query is None:
#             print('None', query_str)
        if res_query is not None and len(res_query)<10:
            print('>>>', query_str)
            print(len(res_query))
    print('@==========================================================================@')

# %%
for idx in range(95000,95500):
    
    _score = score_list[idx]
    investigate(
        anomaly_id_list[idx], 
        train_df, 
        test_df,
        _score
    )
# Out:
# ID  116068918
# Carrier                 584
# ConsigneePanjivaID     1233
# PortOfLading            236
# PortOfUnlading            0
# ShipmentDestination      26
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4477
# hscode_6                 50
# Name: 41898, dtype: int64
# -------------> Filter Valid
# Score  0.7350806593894958
# 584
# 1233
# 236
# 0
# 26
# 81
# 81
# 4477
# 50
# ::> Carrier -0.007047368637631641
# [[ ConsigneePanjivaID 0.18429571062629735 ]]
# ::> PortOfLading 0.06760882182655184
# ::> PortOfUnlading 0.029924892042672794
# [[ ShipmentDestination 0.24617104199971734 ]]
# [[ ShipmentOrigin 0.2896446005968335 ]]
# [[ ShipperCountry 0.19534922220904555 ]]
# ::> ShipperPanjivaID -0.27891570383534176
# [[ hscode_6 0.24234573268082613 ]]
# {'Carrier': 'SHKK - Schenkerocean Limited', 'ConsigneePanjivaID': 44210348.0, 'PortOfLading': 'Ningpo, China', 'PortOfUnlading': 'Baltimore, Maryland', 'ShipmentDestination': 'Baltimore, Maryland', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 45993599.0, 'hscode_6': 940360}
# >>>  ConsigneePanjivaID == 1233 &  PortOfUnlading == 0
# 0
# >>>  ConsigneePanjivaID == 1233 &  ShipmentDestination == 26
# 0
# @==========================================================================@
# ID  116087422
# Carrier                 514
# ConsigneePanjivaID     4716
# PortOfLading             38
# PortOfUnlading           15
# ShipmentDestination     104
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       6116
# hscode_6                 26
# Name: 36590, dtype: int64
# -------------> Filter Valid
# Score  0.7350858449935913
# 514
# 4716
# 38
# 15
# 104
# 81
# 81
# 6116
# 26
# ::> Carrier -0.12374187052531846
# [[ ConsigneePanjivaID 0.25728274495489706 ]]
# ::> PortOfLading 0.06814202489409313
# [[ PortOfUnlading 0.1567501309298166 ]]
# [[ ShipmentDestination 0.11061231609483217 ]]
# [[ ShipmentOrigin 0.4486390296436404 ]]
# [[ ShipperCountry 0.12501076751058346 ]]
# ::> ShipperPanjivaID -0.43192518554037496
# [[ hscode_6 0.3586129094363199 ]]
# {'Carrier': 'AMAW - Apex Shipping Co', 'ConsigneePanjivaID': 27846094.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'The Port of Los Angeles, Los Angeles, California', 'ShipmentDestination': 'The Port of Los Angeles, Los Angeles, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 33779023.0, 'hscode_6': 940190}
# >>>  ShipmentDestination == 104 &  ShipperPanjivaID == 6116
# 8
# @==========================================================================@
# ID  117268250
# Carrier                  24
# ConsigneePanjivaID     3450
# PortOfLading             46
# PortOfUnlading           15
# ShipmentDestination     104
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       1573
# hscode_6                 50
# Name: 81921, dtype: int64
# -------------> Filter Valid
# Score  0.7350889444351196
# 24
# 3450
# 46
# 15
# 104
# 81
# 81
# 1573
# 50
# ::> Carrier 0.014015508917090967
# [[ ConsigneePanjivaID 0.25605891323521285 ]]
# ::> PortOfLading 0.07487164890537854
# [[ PortOfUnlading 0.2332264105219048 ]]
# [[ ShipmentDestination 0.13644435823531023 ]]
# [[ ShipmentOrigin 0.36682937759117046 ]]
# ::> ShipperCountry 0.07959421316022634
# ::> ShipperPanjivaID -0.4915906449798855
# [[ hscode_6 0.2999365435444299 ]]
# {'Carrier': 'HYSL - Hecny Shipping Limited', 'ConsigneePanjivaID': 25381097.0, 'PortOfLading': 'Yantian, China', 'PortOfUnlading': 'The Port of Los Angeles, Los Angeles, California', 'ShipmentDestination': 'The Port of Los Angeles, Los Angeles, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 4168327.0, 'hscode_6': 940360}
# >>>  ConsigneePanjivaID == 3450 &  ShipperPanjivaID == 1573
# 8
# @==========================================================================@
# ID  114407864
# Carrier                  87
# ConsigneePanjivaID      965
# PortOfLading            198
# PortOfUnlading           15
# ShipmentDestination      82
# ShipmentOrigin           30
# ShipperCountry           30
# ShipperPanjivaID       5549
# hscode_6                 50
# Name: 3208, dtype: int64
# -------------> Filter Valid
# Score  0.7350987792015076
# 87
# 965
# 198
# 15
# 82
# 30
# 30
# 5549
# 50
# ::> Carrier 0.1018487162507051
# [[ ConsigneePanjivaID 0.3328234035689235 ]]
# [[ PortOfLading 0.32987985621470617 ]]
# ::> PortOfUnlading 0.062439189683098056
# ::> ShipmentDestination 0.09102103214964169
# [[ ShipmentOrigin 0.3153861727287532 ]]
# [[ ShipperCountry 0.1929635310065456 ]]
# ::> ShipperPanjivaID -0.4906574387196131
# ::> hscode_6 0.03369289317278834
# {'Carrier': 'LUFR - Laufer Group International Ltd', 'ConsigneePanjivaID': 27857735.0, 'PortOfLading': 'Kaohsiung, Taiwan', 'PortOfUnlading': 'The Port of Los Angeles, Los Angeles, California', 'ShipmentDestination': 'The International Port of Memphis, Memphis, Tennessee', 'ShipmentOrigin': 'Vietnam', 'ShipperCountry': 'Vietnam', 'ShipperPanjivaID': 25420336.0, 'hscode_6': 940360}
# >>>  Carrier == 87 &  ConsigneePanjivaID == 965
# 1
# >>>  Carrier == 87 &  ShipperPanjivaID == 5549
# 0
# >>>  ConsigneePanjivaID == 965 &  ShipmentDestination == 82
# 0
# >>>  ShipmentDestination == 82 &  ShipperPanjivaID == 5549
# 0
# @==========================================================================@
# ID  117312441
# Carrier                 217
# ConsigneePanjivaID     5918
# PortOfLading             38
# PortOfUnlading           41
# ShipmentDestination      11
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       1159
# hscode_6                 50
# Name: 71782, dtype: int64
# -------------> Filter Valid
# Score  0.7351066470146179
# 217
# 5918
# 38
# 41
# 11
# 81
# 81
# 1159
# 50
# ::> Carrier 0.00024177302951591242
# [[ ConsigneePanjivaID 0.35654072762126265 ]]
# ::> PortOfLading 0.002331764033960358
# ::> PortOfUnlading 0.10448209439042758
# [[ ShipmentDestination 0.21810161760687843 ]]
# [[ ShipmentOrigin 0.35183479963990333 ]]
# [[ ShipperCountry 0.13637334617766342 ]]
# ::> ShipperPanjivaID -0.3768400772906812
# [[ hscode_6 0.17634019438168963 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 46006162.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Georgia Ports Authority, Savannah, Georgia', 'ShipmentDestination': 'Georgia Ports Authority, Savannah, Georgia', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 1282764.0, 'hscode_6': 940360}
# >>>  PortOfUnlading == 41 &  ShipperPanjivaID == 1159
# 7
# >>>  ShipmentDestination == 11 &  ShipperPanjivaID == 1159
# 7
# @==========================================================================@
# ID  114619832
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 2952, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114619897
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 4119, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114619833
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 4121, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113654071
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 4578, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114619952
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 7931, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113654379
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 8370, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113654378
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 10545, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113654372
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 11081, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113654377
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 12208, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114919593
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 12339, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113654373
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 13956, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114238423
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 14587, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114238490
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 15043, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114238424
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 15645, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114919512
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 15706, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114238422
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 16791, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113910302
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 17328, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114619951
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 17908, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114238421
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 18426, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113910165
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 18438, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113653920
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 18912, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113910300
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 19569, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114238425
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 20005, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113910105
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 20064, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114238491
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 20612, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113654375
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 22817, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114919591
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 22948, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113910303
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 23454, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113910301
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 25126, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113654374
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 26854, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114919105
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 27534, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114919634
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 28070, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113909902
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 29729, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  114919112
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 30361, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113654371
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 30846, dtype: int64
# -------------> Filter Valid
# Score  0.7351223826408386
# 217
# 248
# 38
# 51
# 15
# 81
# 81
# 4858
# 21
# ::> Carrier 0.06934820752253633
# [[ ConsigneePanjivaID 0.1814505891567908 ]]
# [[ PortOfLading 0.10789539443746626 ]]
# ::> PortOfUnlading 0.09413333520468357
# [[ ShipmentDestination 0.2207517672846324 ]]
# [[ ShipmentOrigin 0.2888932664446339 ]]
# [[ ShipperCountry 0.13980480672414372 ]]
# ::> ShipperPanjivaID -0.34362756030339997
# [[ hscode_6 0.21077404006804432 ]]
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 2065570.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 35313007.0, 'hscode_6': 940161}
# @==========================================================================@
# ID  113910307
# Carrier                 217
# ConsigneePanjivaID      248
# PortOfLading             38
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4858
# hscode_6                 21
# Name: 30889, dtype: int64
# ...
# @==========================================================================@
# ID  113612081
# Carrier                 338
# ConsigneePanjivaID     1702
# PortOfLading             46
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       3407
# hscode_6                 50
# Name: 7422, dtype: int64
# -------------> Filter Valid
# Score  0.7364926338195801
# 338
# 1702
# 46
# 51
# 15
# 81
# 81
# 3407
# 50
# ::> Carrier 0.03793512866277976
# [[ ConsigneePanjivaID 0.21753595969320733 ]]
# ::> PortOfLading 0.00980247834119946
# ::> PortOfUnlading 0.09736282347197579
# [[ ShipmentDestination 0.1854644037680854 ]]
# [[ ShipmentOrigin 0.2710588357760316 ]]
# [[ ShipperCountry 0.20686776430791748 ]]
# ::> ShipperPanjivaID -0.4029544416271756
# [[ hscode_6 0.3478908757174993 ]]
# {'Carrier': 'COSU - Cosco Shipping Lines Co Ltd', 'ConsigneePanjivaID': 27959959.0, 'PortOfLading': 'Yantian, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 4897547.0, 'hscode_6': 940360}
# >>>  PortOfUnlading == 51 &  ShipperPanjivaID == 3407
# 5
# >>>  ShipmentDestination == 15 &  ShipperPanjivaID == 3407
# 5
# @==========================================================================@
# ID  113612115
# Carrier                 338
# ConsigneePanjivaID     1702
# PortOfLading             46
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       3407
# hscode_6                 50
# Name: 29261, dtype: int64
# -------------> Filter Valid
# Score  0.7364926338195801
# 338
# 1702
# 46
# 51
# 15
# 81
# 81
# 3407
# 50
# ::> Carrier 0.03793512866277976
# [[ ConsigneePanjivaID 0.21753595969320733 ]]
# ::> PortOfLading 0.00980247834119946
# ::> PortOfUnlading 0.09736282347197579
# [[ ShipmentDestination 0.1854644037680854 ]]
# [[ ShipmentOrigin 0.2710588357760316 ]]
# [[ ShipperCountry 0.20686776430791748 ]]
# ::> ShipperPanjivaID -0.4029544416271756
# [[ hscode_6 0.3478908757174993 ]]
# {'Carrier': 'COSU - Cosco Shipping Lines Co Ltd', 'ConsigneePanjivaID': 27959959.0, 'PortOfLading': 'Yantian, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 4897547.0, 'hscode_6': 940360}
# >>>  PortOfUnlading == 51 &  ShipperPanjivaID == 3407
# 5
# >>>  ShipmentDestination == 15 &  ShipperPanjivaID == 3407
# 5
# @==========================================================================@
# ID  115005449
# Carrier                  65
# ConsigneePanjivaID     4272
# PortOfLading             45
# PortOfUnlading           12
# ShipmentDestination      34
# ShipmentOrigin           30
# ShipperCountry           30
# ShipperPanjivaID       1476
# hscode_6                 48
# Name: 57946, dtype: int64
# -------------> Filter Valid
# Score  0.7365552186965942
# 65
# 4272
# 45
# 12
# 34
# 30
# 30
# 1476
# 48
# ::> Carrier -0.1133498681030229
# [[ ConsigneePanjivaID 0.2984430907526985 ]]
# ::> PortOfLading 0.0878450335955299
# [[ PortOfUnlading 0.23086931997942262 ]]
# [[ ShipmentDestination 0.23727084456883016 ]]
# [[ ShipmentOrigin 0.34321364713509206 ]]
# [[ ShipperCountry 0.1289582565202094 ]]
# ::> ShipperPanjivaID -0.36177335317032594
# [[ hscode_6 0.11955710690225081 ]]
# {'Carrier': 'ITGB - Interglobo North America Inc', 'ConsigneePanjivaID': 27810680.0, 'PortOfLading': 'Singapore, Singapore', 'PortOfUnlading': 'New York, New York', 'ShipmentDestination': 'New York, New York', 'ShipmentOrigin': 'Vietnam', 'ShipperCountry': 'Vietnam', 'ShipperPanjivaID': 2627692.0, 'hscode_6': 940350}
# >>>  Carrier == 65 &  ConsigneePanjivaID == 4272
# 0
# >>>  Carrier == 65 &  ShipperPanjivaID == 1476
# 0
# @==========================================================================@
# ID  116644411
# Carrier                  20
# ConsigneePanjivaID     3426
# PortOfLading            236
# PortOfUnlading           15
# ShipmentDestination     104
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID         27
# hscode_6                 74
# Name: 71095, dtype: int64
# ID  116125192
# Carrier                 195
# ConsigneePanjivaID      802
# PortOfLading             46
# PortOfUnlading           41
# ShipmentDestination      11
# ShipmentOrigin          116
# ShipperCountry          115
# ShipperPanjivaID       3904
# hscode_6                 50
# Name: 57636, dtype: int64
# -------------> Filter Valid
# Score  0.7365756630897522
# 195
# 802
# 46
# 41
# 11
# 116
# 115
# 3904
# 50
# [[ Carrier 0.1341321828136244 ]]
# [[ ConsigneePanjivaID 0.1207699108250135 ]]
# ::> PortOfLading 0.07862576411696122
# ::> PortOfUnlading 0.06816557480413342
# [[ ShipmentDestination 0.2108529980816276 ]]
# [[ ShipmentOrigin 0.26406724992226543 ]]
# [[ ShipperCountry 0.2473463072240857 ]]
# ::> ShipperPanjivaID -0.3541380832285505
# [[ hscode_6 0.20123537133121416 ]]
# {'Carrier': 'CMDU - Cma Cgm', 'ConsigneePanjivaID': 27824117.0, 'PortOfLading': 'Yantian, China', 'PortOfUnlading': 'Georgia Ports Authority, Savannah, Georgia', 'ShipmentDestination': 'Georgia Ports Authority, Savannah, Georgia', 'ShipmentOrigin': 'Hong Kong', 'ShipperCountry': 'Hong Kong', 'ShipperPanjivaID': 35341335.0, 'hscode_6': 940360}
# >>>  ConsigneePanjivaID == 802 &  PortOfLading == 46
# 7
# >>>  ConsigneePanjivaID == 802 &  ShipperPanjivaID == 3904
# 7
# >>>  ConsigneePanjivaID == 802 &  hscode_6 == 50
# 6
# @==========================================================================@
# ID  113837278
# Carrier                 195
# ConsigneePanjivaID     5918
# PortOfLading             31
# PortOfUnlading           11
# ShipmentDestination     100
# ShipmentOrigin            6
# ShipperCountry            6
# ShipperPanjivaID         65
# hscode_6                 48
# Name: 17708, dtype: int64
# -------------> Filter Valid
# Score  0.7365794181823729
# 195
# 5918
# 31
# 11
# 100
# 6
# 6
# 65
# 48
# ::> Carrier 0.07534203827823364
# [[ ConsigneePanjivaID 0.32608309108070593 ]]
# [[ PortOfLading 0.16208686952833817 ]]
# ::> PortOfUnlading 0.09653088381694513
# [[ ShipmentDestination 0.20827291828282513 ]]
# [[ ShipmentOrigin 0.13713547359531406 ]]
# [[ ShipperCountry 0.1396395724543585 ]]
# ::> ShipperPanjivaID -0.33681481084064274
# [[ hscode_6 0.16278546766050148 ]]
# {'Carrier': 'CMDU - Cma Cgm', 'ConsigneePanjivaID': 46006162.0, 'PortOfLading': 'Busan, South Korea', 'PortOfUnlading': 'Port of Seattle, Seattle, Washington', 'ShipmentDestination': 'Port of Seattle, Seattle, Washington', 'ShipmentOrigin': 'Italy', 'ShipperCountry': 'Italy', 'ShipperPanjivaID': 1179911.0, 'hscode_6': 940350}
# @==========================================================================@
# ID  116119700
# Carrier                 195
# ConsigneePanjivaID     5918
# PortOfLading             31
# PortOfUnlading           11
# ShipmentDestination     100
# ShipmentOrigin            6
# ShipperCountry            6
# ShipperPanjivaID         65
# hscode_6                 48
# Name: 93837, dtype: int64
# -------------> Filter Valid
# Score  0.7365794181823729
# 195
# 5918
# 31
# 11
# 100
# 6
# 6
# 65
# 48
# ::> Carrier 0.07534203827823364
# [[ ConsigneePanjivaID 0.32608309108070593 ]]
# [[ PortOfLading 0.16208686952833817 ]]
# ::> PortOfUnlading 0.09653088381694513
# [[ ShipmentDestination 0.20827291828282513 ]]
# [[ ShipmentOrigin 0.13713547359531406 ]]
# [[ ShipperCountry 0.1396395724543585 ]]
# ::> ShipperPanjivaID -0.33681481084064274
# [[ hscode_6 0.16278546766050148 ]]
# {'Carrier': 'CMDU - Cma Cgm', 'ConsigneePanjivaID': 46006162.0, 'PortOfLading': 'Busan, South Korea', 'PortOfUnlading': 'Port of Seattle, Seattle, Washington', 'ShipmentDestination': 'Port of Seattle, Seattle, Washington', 'ShipmentOrigin': 'Italy', 'ShipperCountry': 'Italy', 'ShipperPanjivaID': 1179911.0, 'hscode_6': 940350}
# @==========================================================================@
# ID  113698988
# Carrier                  81
# ConsigneePanjivaID     5361
# PortOfLading            139
# PortOfUnlading           14
# ShipmentDestination     103
# ShipmentOrigin            6
# ShipperCountry            6
# ShipperPanjivaID       6514
# hscode_6                 21
# Name: 11965, dtype: int64
# -------------> Filter Valid
# Score  0.7365886569023132
# 81
# 5361
# 139
# 14
# 103
# 6
# 6
# 6514
# 21
# ::> Carrier -0.13024579880606157
# [[ ConsigneePanjivaID 0.3474397223617244 ]]
# ::> PortOfLading 0.07979027166662223
# [[ PortOfUnlading 0.2912617765788408 ]]
# [[ ShipmentDestination 0.20928047279803355 ]]
# [[ ShipmentOrigin 0.2919719368649696 ]]
# ::> ShipperCountry -0.013917345848373033
# ::> ShipperPanjivaID -0.19906978646885545
# ::> hscode_6 0.09456060206115625
# {'Carrier': 'BANQ - Blue Anchor America Line (Blue Anchor Line)', 'ConsigneePanjivaID': 27816958.0, 'PortOfLading': 'Genoa, Italy', 'PortOfUnlading': 'Port of Virginia, Norfolk, Virginia', 'ShipmentDestination': 'Port of Virginia, Norfolk, Virginia', 'ShipmentOrigin': 'Italy', 'ShipperCountry': 'Italy', 'ShipperPanjivaID': 30864884.0, 'hscode_6': 940161}
# >>>  Carrier == 81 &  ConsigneePanjivaID == 5361
# 4
# >>>  ConsigneePanjivaID == 5361 &  PortOfLading == 139
# 4
# >>>  ConsigneePanjivaID == 5361 &  PortOfUnlading == 14
# 4
# >>>  ConsigneePanjivaID == 5361 &  ShipmentDestination == 103
# 4
# >>>  ConsigneePanjivaID == 5361 &  ShipperPanjivaID == 6514
# 4
# @==========================================================================@
# ID  115821364
# Carrier                 482
# ConsigneePanjivaID     4525
# PortOfLading            236
# PortOfUnlading           15
# ShipmentDestination      30
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID       4477
# hscode_6                 50
# Name: 38640, dtype: int64
# -------------> Filter Valid
# Score  0.7365995049476624
# 482
# 4525
# 236
# 15
# 30
# 81
# 81
# 4477
# 50
# ::> Carrier -0.07802662550212927
# [[ ConsigneePanjivaID 0.27552641276445816 ]]
# ::> PortOfLading 0.042633715739326235
# [[ PortOfUnlading 0.3102041605781951 ]]
# ::> ShipmentDestination 0.10261018035949547
# [[ ShipmentOrigin 0.40501379189715553 ]]
# ::> ShipperCountry 0.09326313069364632
# ::> ShipperPanjivaID -0.4707809058994142
# [[ hscode_6 0.29064006170615103 ]]
# {'Carrier': 'OERT - Orient Express Container Co Ltd', 'ConsigneePanjivaID': 45703510.0, 'PortOfLading': 'Ningpo, China', 'PortOfUnlading': 'The Port of Los Angeles, Los Angeles, California', 'ShipmentDestination': 'Illinois International Port District, Chicago, Illinois', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 45993599.0, 'hscode_6': 940360}
# >>>  ConsigneePanjivaID == 4525 &  PortOfLading == 236
# 0
# >>>  ConsigneePanjivaID == 4525 &  PortOfUnlading == 15
# 4
# >>>  ConsigneePanjivaID == 4525 &  ShipperPanjivaID == 4477
# 0
# >>>  ShipmentDestination == 30 &  ShipperPanjivaID == 4477
# 3
# @==========================================================================@
# ID  115400335
# Carrier                 286
# ConsigneePanjivaID     2268
# PortOfLading             46
# PortOfUnlading           51
# ShipmentDestination      15
# ShipmentOrigin           30
# ShipperCountry           30
# ShipperPanjivaID       5964
# hscode_6                 50
# Name: 60065, dtype: int64
# -------------> Filter Valid
# Score  0.7366055846214294
# 286
# 2268
# 46
# 51
# 15
# 30
# 30
# 5964
# 50
# ::> Carrier 0.0507098319173402
# [[ ConsigneePanjivaID 0.3351193640375988 ]]
# [[ PortOfLading 0.2155756249469765 ]]
# [[ PortOfUnlading 0.12579337625933165 ]]
# ::> ShipmentDestination 0.10133035745618975
# [[ ShipmentOrigin 0.3019851520652675 ]]
# [[ ShipperCountry 0.17191738895241884 ]]
# ::> ShipperPanjivaID -0.4698609515213265
# [[ hscode_6 0.13852071134982313 ]]
# {'Carrier': 'WWOL - Worldwide Logistics Ltd (Worldwide Ocean Line Worldwide Logistics (Usa))', 'ConsigneePanjivaID': 27864982.0, 'PortOfLading': 'Yantian, China', 'PortOfUnlading': 'Port of Long Beach, Long Beach, California', 'ShipmentDestination': 'Port of Long Beach, Long Beach, California', 'ShipmentOrigin': 'Vietnam', 'ShipperCountry': 'Vietnam', 'ShipperPanjivaID': 40856151.0, 'hscode_6': 940360}
# >>>  Carrier == 286 &  ShipperPanjivaID == 5964
# 5
# @==========================================================================@
# ID  115276432
# Carrier                  62
# ConsigneePanjivaID     5718
# PortOfLading             38
# PortOfUnlading           15
# ShipmentDestination     104
# ShipmentOrigin           81
# ShipperCountry           81
# ShipperPanjivaID        766
# hscode_6                 21
# Name: 62407, dtype: int64
# -------------> Filter Valid
# Score  0.7366246581077576
# 62
# 5718
# 38
# 15
# 104
# 81
# 81
# 766
# 21
# ::> Carrier 0.06626213075560994
# [[ ConsigneePanjivaID 0.2683998179286233 ]]
# [[ PortOfLading 0.12130778961393733 ]]
# [[ PortOfUnlading 0.1253134255662183 ]]
# [[ ShipmentDestination 0.1477779322420104 ]]
# [[ ShipmentOrigin 0.19647996401756693 ]]
# [[ ShipperCountry 0.1228994216799402 ]]
# ::> ShipperPanjivaID -0.33119656119029844
# [[ hscode_6 0.25386840369639574 ]]
# {'Carrier': 'HDMU - Hyundai Merchant Marine', 'ConsigneePanjivaID': 27851648.0, 'PortOfLading': 'Shanghai, China', 'PortOfUnlading': 'The Port of Los Angeles, Los Angeles, California', 'ShipmentDestination': 'The Port of Los Angeles, Los Angeles, California', 'ShipmentOrigin': 'China', 'ShipperCountry': 'China', 'ShipperPanjivaID': 5180564.0, 'hscode_6': 940161}
# >>>  Carrier == 62 &  ConsigneePanjivaID == 5718
# 0
# >>>  Carrier == 62 &  ShipperPanjivaID == 766
# 0
# >>>  ConsigneePanjivaID == 5718 &  PortOfUnlading == 15
# 0
# >>>  ConsigneePanjivaID == 5718 &  ShipmentDestination == 104
# 0
# @==========================================================================@
# ID  114924794
# Carrier                 217
# ConsigneePanjivaID     5918
# PortOfLading             45
# PortOfUnlading            0
# ShipmentDestination      26
# ShipmentOrigin           30
# ShipperCountry           30
# ShipperPanjivaID       1605
# hscode_6                 50
# Name: 37416, dtype: int64
# -------------> Filter Valid
# Score  0.7366253137588501
# 217
# 5918
# 45
# 0
# 26
# 30
# 30
# 1605
# 50
# [[ Carrier 0.15125377407432833 ]]
# [[ ConsigneePanjivaID 0.3712592981520311 ]]
# [[ PortOfLading 0.17342754424889859 ]]
# ::> PortOfUnlading 0.09649537778148512
# [[ ShipmentDestination 0.2892657738329947 ]]
# [[ ShipmentOrigin 0.1672696802120695 ]]
# [[ ShipperCountry 0.13281270258700886 ]]
# ::> ShipperPanjivaID -0.36974064434428855
# ::> hscode_6 -0.040930514618792824
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 46006162.0, 'PortOfLading': 'Singapore, Singapore', 'PortOfUnlading': 'Baltimore, Maryland', 'ShipmentDestination': 'Baltimore, Maryland', 'ShipmentOrigin': 'Vietnam', 'ShipperCountry': 'Vietnam', 'ShipperPanjivaID': 1317619.0, 'hscode_6': 940360}
# >>>  PortOfUnlading == 0 &  ShipperPanjivaID == 1605
# 6
# >>>  ShipmentDestination == 26 &  ShipperPanjivaID == 1605
# 6
# @==========================================================================@
# ID  114924806
# Carrier                 217
# ConsigneePanjivaID     5918
# PortOfLading             45
# PortOfUnlading            0
# ShipmentDestination      26
# ShipmentOrigin           30
# ShipperCountry           30
# ShipperPanjivaID       1605
# hscode_6                 50
# Name: 69575, dtype: int64
# -------------> Filter Valid
# Score  0.7366253137588501
# 217
# 5918
# 45
# 0
# 26
# 30
# 30
# 1605
# 50
# [[ Carrier 0.15125377407432833 ]]
# [[ ConsigneePanjivaID 0.3712592981520311 ]]
# [[ PortOfLading 0.17342754424889859 ]]
# ::> PortOfUnlading 0.09649537778148512
# [[ ShipmentDestination 0.2892657738329947 ]]
# [[ ShipmentOrigin 0.1672696802120695 ]]
# [[ ShipperCountry 0.13281270258700886 ]]
# ::> ShipperPanjivaID -0.36974064434428855
# ::> hscode_6 -0.040930514618792824
# {'Carrier': 'MSCU - Msc Mediterranean Shipping Company S A', 'ConsigneePanjivaID': 46006162.0, 'PortOfLading': 'Singapore, Singapore', 'PortOfUnlading': 'Baltimore, Maryland', 'ShipmentDestination': 'Baltimore, Maryland', 'ShipmentOrigin': 'Vietnam', 'ShipperCountry': 'Vietnam', 'ShipperPanjivaID': 1317619.0, 'hscode_6': 940360}
# >>>  PortOfUnlading == 0 &  ShipperPanjivaID == 1605
# 6
# >>>  ShipmentDestination == 26 &  ShipperPanjivaID == 1605
# 6
# @==========================================================================@

# %%
np.percentile(score_list,7)
# Out:
# 0.5180734539031983
